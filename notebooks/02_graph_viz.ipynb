# %% [markdown]
# # 02 - Airport Graph Visualization
#
# Visualize the airport network graph used by the GNN models.
#
# **Objectives:**
# - Plot the airport network (nodes = airports, edges = routes)
# - Show traffic volume per airport
# - Visualize GAT attention weights on the graph
# - Animate delay propagation across the network

# %%
# TODO: Implement after graph builder is complete
