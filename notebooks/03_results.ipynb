# %% [markdown]
# # 03 - Results Comparison
#
# Compare performance across all model phases.
#
# **Objectives:**
# - Compare MAE/RMSE across all models
# - Plot error by prediction horizon (T+1 through T+5)
# - Visualize delay propagation predictions vs actual
# - Generate tables and figures for the thesis

# %%
# TODO: Implement after models are trained
