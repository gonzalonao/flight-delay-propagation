# %% [markdown]
# # 01 - Exploratory Data Analysis
#
# Initial exploration of the Flight Delay Dataset 2018-2022.
#
# **Objectives:**
# - Understand data structure and column types
# - Analyze delay distributions
# - Identify top airports by traffic volume
# - Explore temporal patterns (hour, day, month)
# - Check missing values and data quality

# %%
import pandas as pd
import seaborn as sns

sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns", 30)

# %%
# TODO: Load sample data and begin exploration
